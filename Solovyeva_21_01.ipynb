# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cv = pd.read_csv("drive/My Drive/country_vaccinations.csv" )
cv
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 15 columns]

# %%
print(cv.shape)
# Out:
# (1192, 15)

# %%
print(cv.info())
print(cv.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1192 entries, 0 to 1191
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              1192 non-null   object
#  1   date                                 1192 non-null   object
#  2   total_vaccinations                   1192 non-null   float64
#  3   people_vaccinated                    1192 non-null   float64
#  4   daily_vaccinations                   1192 non-null   float64
#  5   total_vaccinations_per_hundred       1192 non-null   float64
#  6   people_fully_vaccinated_per_hundred  1192 non-null   float64
#  7   daily_vaccinations_per_million       1192 non-null   float64
#  8   vaccines                             1192 non-null   object
#  9   source_name                          1192 non-null   object
#  10  source_website                       1192 non-null   object
# ...

# %%
cv = cv.drop([ 'people_vaccinated_per_hundred', 'people_fully_vaccinated', 'daily_vaccinations_raw' ], axis = 1)
cv
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 12 columns]

# %%
cv.fillna(cv.mean(), inplace=True)
cv
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 11 columns]

# %%
print(cv.isna().sum())
# Out:
# country                                0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
cv = cv.drop([ 'iso_code'], axis = 1)
cv
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 11 columns]

# %%
print (cv['vaccines'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-4c55d6dbf475> in <module>()
# ----> 1 print (cv['vaccines'].value_counts())
#       2
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
# ...

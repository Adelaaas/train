# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ed1ba4a9-401e-4d08-a6ea-136d128e701a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed1ba4a9-401e-4d08-a6ea-136d128e701a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving country_vaccinations.csv to country_vaccinations (1).csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("country_vaccinations.csv")
df
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 15 columns]

# %%
print(df.shape)
print(df.info())
print(df.dtypes)
print("________________________________________")
print(df.isna().sum())
# Out:
# (1192, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1192 entries, 0 to 1191
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              1192 non-null   object
#  1   iso_code                             1047 non-null   object
#  2   date                                 1192 non-null   object
#  3   total_vaccinations                   750 non-null    float64
#  4   people_vaccinated                    705 non-null    float64
#  5   people_fully_vaccinated              140 non-null    float64
#  6   daily_vaccinations_raw               581 non-null    float64
#  7   daily_vaccinations                   1136 non-null   float64
#  8   total_vaccinations_per_hundred       750 non-null    float64
#  9   people_vaccinated_per_hundred        705 non-null    float64
# ...

# %%
for i in range(len(df.dtypes)):
    if df.dtypes[i] == 'object':
         print(df.columns[i], df.dtypes[i])
# Out:
# country object
# iso_code object
# date object
# vaccines object
# source_name object
# source_website object

# %%
df = df.drop(['people_vaccinated','daily_vaccinations_raw', 'people_fully_vaccinated_per_hundred'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-fd03451b8fba> in <module>()
# ----> 1 df = df.drop(['people_vaccinated','daily_vaccinations_raw', 'people_fully_vaccinated_per_hundred'], axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
df
# Out:
#             country  ...                                     source_website
# 0           1335.22  ...                                            1335.22
# 1         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...             ...  ...                                                ...
# 1150  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1151  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1152  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1153  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1154        1335.22  ...                                            1335.22
#
# [1051 rows x 12 columns]

# %%
df['total_vaccinations'] = df['total_vaccinations'].fillna(df['total_vaccinations'].mean)                                             
df['total_vaccinations_per_hundred'] = df['total_vaccinations_per_hundred'].fillna(df['total_vaccinations_per_hundred'].mean)
df['people_vaccinated_per_hundred'] = df['people_vaccinated_per_hundred'].fillna(df['people_vaccinated_per_hundred'].mean)
df['people_fully_vaccinated'] = df['people_fully_vaccinated'].fillna(df['people_fully_vaccinated'].mean)   
#удаление пустых значений (некоторые значения я удалил но случайно коды удалились)                  
df.isna().sum()
# Out:
# country                           0
# iso_code                          0
# date                              0
# total_vaccinations                0
# people_fully_vaccinated           0
# daily_vaccinations                0
# total_vaccinations_per_hundred    0
# people_vaccinated_per_hundred     0
# daily_vaccinations_per_million    0
# vaccines                          0
# source_name                       0
# source_website                    0
# dtype: int64

# %%
df
# Out:
#             country  ...                                     source_website
# 0           1335.22  ...                                            1335.22
# 1         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4         Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...             ...  ...                                                ...
# 1150  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1151  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1152  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1153  United States  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1154        1335.22  ...                                            1335.22
#
# [1051 rows x 12 columns]

# %%
df['vaccines'].value_counts()
# Out:
# Pfizer/BioNTech                        606
# Moderna, Pfizer/BioNTech               208
# 1335.2227112676057                      56
# Sputnik V                               51
# Pfizer/BioNTech, Sinopharm              42
# CNBG, Sinovac                           36
# Oxford/AstraZeneca, Pfizer/BioNTech     30
# Sinovac                                 11
# Sinopharm                                7
# Covaxin, Covishield                      4
# Name: vaccines, dtype: int64

# %%
df['source_name'].unique
# Out:
# <bound method Series.unique of 0                                          1335.22
# 1                               Ministry of Health
# 2                               Ministry of Health
# 3                               Ministry of Health
# 4                               Ministry of Health
#                            ...
# 1150    Centers for Disease Control and Prevention
# 1151    Centers for Disease Control and Prevention
# 1152    Centers for Disease Control and Prevention
# 1153    Centers for Disease Control and Prevention
# 1154                                       1335.22
# Name: source_name, Length: 1051, dtype: object>

# %%
a = df.groupby('country')
a['total_vaccinations'].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-811475989d15> in <module>()
#       1 a = df.groupby('country')
# ----> 2 a['total_vaccinations'].max()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in max(self, numeric_only, min_count)
#    1558     def max(self, numeric_only: bool = False, min_count: int = -1):
#    1559         return self._agg_general(
# -> 1560             numeric_only=numeric_only, min_count=min_count, alias="max", npfunc=np.max
#    1561         )
#    1562
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1015         # apply a non-cython aggregation
#    1016         if result is None:
# -> 1017             result = self.aggregate(lambda x: npfunc(x, axis=self.axis))
# ...

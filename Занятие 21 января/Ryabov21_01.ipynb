# %%
import pandas as pd

df = pd.read_csv("C:\\Users\In9.var\Desktop\Projects\data\country_vaccinations.csv")
df
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Argentina      ARG  2020-12-29               700.0                NaN
# 1     Argentina      ARG  2020-12-30                 NaN                NaN
# 2     Argentina      ARG  2020-12-31             32013.0                NaN
# 3     Argentina      ARG  2021-01-01                 NaN                NaN
# 4     Argentina      ARG  2021-01-02                 NaN                NaN
# ...         ...      ...         ...                 ...                ...
# 1187      Wales      NaN  2021-01-15                 NaN                NaN
# 1188      Wales      NaN  2021-01-16                 NaN                NaN
# 1189      Wales      NaN  2021-01-17            151938.0           151737.0
# 1190      Wales      NaN  2021-01-18            162197.0           161932.0
# 1191      Wales      NaN  2021-01-19            176186.0           175816.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN             15656.0
# 2                         NaN                     NaN             15656.0
# 3                         NaN                     NaN             11070.0
# 4                         NaN                     NaN              8776.0
# ...                       ...                     ...                 ...
# 1187                      NaN                     NaN              8468.0
# 1188                      NaN                     NaN              8935.0
# 1189                    201.0                     NaN              9403.0
# 1190                    265.0                 10259.0             10123.0
# 1191                    370.0                 13989.0             10672.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                               0.00                            NaN
# 1                                NaN                            NaN
# 2                               0.07                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 1187                             NaN                            NaN
# 1188                             NaN                            NaN
# 1189                            4.82                           4.81
# 1190                            5.14                           5.14
# 1191                            5.59                           5.58
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                     NaN                             NaN
# 1                                     NaN                           346.0
# 2                                     NaN                           346.0
# 3                                     NaN                           245.0
# 4                                     NaN                           194.0
# ...                                   ...                             ...
# 1187                                  NaN                          2686.0
# 1188                                  NaN                          2834.0
# 1189                                 0.01                          2982.0
# 1190                                 0.01                          3211.0
# 1191                                 0.01                          3385.0
#
#                                  vaccines                       source_name  \
# 0                               Sputnik V                Ministry of Health
# 1                               Sputnik V                Ministry of Health
# 2                               Sputnik V                Ministry of Health
# 3                               Sputnik V                Ministry of Health
# 4                               Sputnik V                Ministry of Health
# ...                                   ...                               ...
# 1187  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1188  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1189  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1190  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
# 1191  Oxford/AstraZeneca, Pfizer/BioNTech  Government of the United Kingdom
#
#                                          source_website
# 0     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...                                                 ...
# 1187  https://coronavirus.data.gov.uk/details/health...
# 1188  https://coronavirus.data.gov.uk/details/health...
# 1189  https://coronavirus.data.gov.uk/details/health...
# 1190  https://coronavirus.data.gov.uk/details/health...
# 1191  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 15 columns]

# %%
print(df.shape)
print(df.isna().sum())
# Out:
# (1192, 15)
# country                                   0
# iso_code                                145
# date                                      0
# total_vaccinations                      442
# people_vaccinated                       487
# people_fully_vaccinated                1052
# daily_vaccinations_raw                  611
# daily_vaccinations                       56
# total_vaccinations_per_hundred          442
# people_vaccinated_per_hundred           487
# people_fully_vaccinated_per_hundred    1052
# daily_vaccinations_per_million           56
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
df.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
for i in range(len(df.dtypes)):
    if df.dtypes[i] == 'object':
        print(df.columns[i], df.dtypes[i])
# Out:
# country object
# iso_code object
# date object
# vaccines object
# source_name object
# source_website object

# %%
df = df.drop(['people_fully_vaccinated', 'daily_vaccinations_raw', 'people_fully_vaccinated_per_hundred'], axis=1)
df.isna().sum()
# Out:
# country                             0
# iso_code                          145
# date                                0
# total_vaccinations                442
# people_vaccinated                 487
# daily_vaccinations                 56
# total_vaccinations_per_hundred    442
# people_vaccinated_per_hundred     487
# daily_vaccinations_per_million     56
# vaccines                            0
# source_name                         0
# source_website                      0
# dtype: int64

# %%
#df[df['people_vaccinated_per_hundred'].isna()] = df['people_vaccinated_per_hundred'].mean()
#df[df['total_vaccinations'].isna()] = df['total_vaccinations'].mean()
#df[df['people_vaccinated'].isna()] = df['people_vaccinated'].mean()
#df[df['daily_vaccinations'].isna()] = df['daily_vaccinations'].mean()
#df[df['total_vaccinations_per_hundred'].isna()]= df['total_vaccinations_per_hundred'].mean()
#df[df['daily_vaccinations_per_million'].isna()] = df['daily_vaccinations_per_million'].mean()
df['total_vaccinations'].fillna(df['total_vaccinations'].mean())
df.isna().sum()
# Out:
# country                            0
# iso_code                          47
# date                               0
# total_vaccinations                 0
# people_vaccinated                  0
# daily_vaccinations                 0
# total_vaccinations_per_hundred     0
# people_vaccinated_per_hundred      0
# daily_vaccinations_per_million     0
# vaccines                           0
# source_name                        0
# source_website                     0
# dtype: int64

# %%
df = df.drop(df.loc[df['iso_code'].isna()].index, axis=0)
df.isna().sum()
# Out:
# country                           0
# iso_code                          0
# date                              0
# total_vaccinations                0
# people_vaccinated                 0
# daily_vaccinations                0
# total_vaccinations_per_hundred    0
# people_vaccinated_per_hundred     0
# daily_vaccinations_per_million    0
# vaccines                          0
# source_name                       0
# source_website                    0
# dtype: int64

# %%
df.shape
# Out:
# (1145, 12)

# %%
val = {}
for i in df['vaccines'].values:
    if i not in val.keys():
        val[i] = 1
    else:
        val[i] += 1
for i in val.keys():
    print(i, val[i], sep=': ')
# Out:
# 2.0690212765957434: 487
# Sputnik V: 4
# 18451.252071307474: 51
# Pfizer/BioNTech: 394
# Pfizer/BioNTech, Sinopharm: 38
# Sinovac: 11
# Moderna, Pfizer/BioNTech: 137
# CNBG, Sinovac: 4
# Covaxin, Covishield: 4
# Sinopharm: 3
# Oxford/AstraZeneca, Pfizer/BioNTech: 12

# %%
df['vaccines'].value_counts()
# Out:
# 2.0690212765957434                     487
# Pfizer/BioNTech                        394
# Moderna, Pfizer/BioNTech               137
# 18451.252071307474                      51
# Pfizer/BioNTech, Sinopharm              38
# Oxford/AstraZeneca, Pfizer/BioNTech     12
# Sinovac                                 11
# CNBG, Sinovac                            4
# Covaxin, Covishield                      4
# Sputnik V                                4
# Sinopharm                                3
# Name: vaccines, dtype: int64

# %%
val = {}
for i in df['source_name'].values:
    if i not in val.keys():
        val[i] = 1
    else:
        val[i] += 1
print(len(val.keys()))
for i in val.keys():
    print(i, val[i], sep=': ')
# Out:
# 35
# 2.0690212765957434: 487
# Ministry of Health: 207
# 18451.252071307474: 51
# Sciensano: 19
# Regional governments via Coronavirus Brasil: 4
# COVID-19 Canada Open Data Working Group: 36
# Department of Statistics and Health Information: 13
# National Health Commission: 5
# Statens Serum Institut: 23
# National Health Board: 22
# THL via Helsingin Sanomat: 12
# Robert Koch Institut: 23
# Government of Gibraltar: 7
# Government of Hungary: 2
# Directorate of Health: 1
# Heath Service Executive: 5
# Government of Israel: 32
# Extraordinary commissioner for the Covid-19 emergency: 24
# National Health Service: 24
# Government of Luxembourg: 7
# Secretary of Health: 20
# National Institute for Public Health and the Environment: 10
# Norwegian Institute of Public Health: 23
# Government of Romania: 23
# Russian Direct Investment Fund: 3
# Saudi Health Council: 3
# Government of Serbia: 2
# Extended Programme for Immunisation: 3
# National Institute of Public Health, via Sledilnik: 16
# Public Health Agency of Sweden: 3
# Federal Office of Public Health: 2
# COVID-19 Vaccine Information Platform: 7
# National Emergency Crisis and Disaster Management Authority: 11
# Government of the United Kingdom: 12
# Centers for Disease Control and Prevention: 3

# %%
a = df.groupby('country')
a['total_vaccinations'].max()
# Out:
# country
# 2.0690212765957434      2.069021e+00
# 18451.252071307474      1.845125e+04
# Argentina               2.479330e+05
# Austria                 1.507030e+05
# Bahrain                 1.435960e+05
# Belgium                 1.263280e+05
# Brazil                  2.854300e+04
# Bulgaria                2.222600e+04
# Canada                  6.511390e+05
# Chile                   5.092400e+04
# China                   1.500000e+07
# Costa Rica              2.485900e+04
# Croatia                 5.430400e+04
# Cyprus                  1.022600e+04
# Czechia                 1.082390e+05
# Denmark                 1.820320e+05
# Estonia                 2.047800e+04
# Finland                 6.206100e+04
# France                  5.856640e+05
# Germany                 1.297430e+06
# Gibraltar               7.017000e+03
# Greece                  1.073350e+05
# Hungary                 1.332570e+05
# Iceland                 6.205000e+03
# India                   6.748350e+05
# Ireland                 9.400000e+04
# Israel                  2.936691e+06
# Italy                   1.237328e+06
# Latvia                  1.763300e+04
# Lithuania               6.044700e+04
# Luxembourg              5.294000e+03
# Malta                   1.427600e+04
# Mexico                  4.981220e+05
# Netherlands             1.000000e+05
# Norway                  5.566200e+04
# Oman                    2.804900e+04
# Poland                  5.412290e+05
# Portugal                1.060000e+05
# Romania                 3.083840e+05
# Russia                  1.000000e+06
# Saudi Arabia            2.955300e+05
# Serbia                  1.813600e+04
# Seychelles              7.000000e+03
# Singapore               6.200000e+03
# Slovakia                7.206000e+04
# Slovenia                4.386900e+04
# Spain                   1.025937e+06
# Sweden                  1.467750e+05
# Switzerland             1.100000e+05
# Turkey                  1.052493e+06
# United Arab Emirates    2.161150e+06
# United Kingdom          5.070365e+06
# United States           1.570759e+07
# Name: total_vaccinations, dtype: float64

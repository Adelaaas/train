# %% [markdown]
# # Новый раздел

# %%
import pandas as pd
from sklearn import preprocessing

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-c756ce03-40b9-4879-8c6c-e79b518e595a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c756ce03-40b9-4879-8c6c-e79b518e595a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving country_vaccinations.csv to country_vaccinations.csv

# %% [markdown]
# # Новый раздел

# %%
df=pd.read_csv('country_vaccinations.csv')

# %%
df
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 15 columns]

# %%
df.shape
# Out:
# (1192, 15)

# %%
df.isna().sum()
# Out:
# country                                   0
# iso_code                                145
# date                                      0
# total_vaccinations                      442
# people_vaccinated                       487
# people_fully_vaccinated                1052
# daily_vaccinations_raw                  611
# daily_vaccinations                       56
# total_vaccinations_per_hundred          442
# people_vaccinated_per_hundred           487
# people_fully_vaccinated_per_hundred    1052
# daily_vaccinations_per_million           56
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
df.dtypes
#категороиальные country iso_code date vaccines source_name source_website
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
df=df.drop(["people_fully_vaccinated_per_hundred","people_fully_vaccinated"],axis=1)

# %%
df
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 13 columns]

# %%
a=df["total_vaccinations"].mean()
df["total_vaccinations"]=df['total_vaccinations'].fillna(a)
a=df["people_vaccinated"].mean()
df["people_vaccinated"]=df['people_vaccinated'].fillna(a)
a=df["daily_vaccinations_raw"].mean()
df["daily_vaccinations_raw"]=df['daily_vaccinations_raw'].fillna(a)
a=df["daily_vaccinations"].mean()
df["daily_vaccinations"]=df['daily_vaccinations'].fillna(a)
a=df["total_vaccinations_per_hundred"].mean()
df["total_vaccinations_per_hundred"]=df['total_vaccinations_per_hundred'].fillna(a)
a=df["people_vaccinated_per_hundred"].mean()
df["people_vaccinated_per_hundred"]=df['people_vaccinated_per_hundred'].fillna(a)
a=df["daily_vaccinations_per_million"].mean()
df["daily_vaccinations_per_million"]=df['daily_vaccinations_per_million'].fillna(a)

# %%
df
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# country                             0
# iso_code                          145
# date                                0
# total_vaccinations                  0
# people_vaccinated                   0
# daily_vaccinations_raw              0
# daily_vaccinations                  0
# total_vaccinations_per_hundred      0
# people_vaccinated_per_hundred       0
# daily_vaccinations_per_million      0
# vaccines                            0
# source_name                         0
# source_website                      0
# dtype: int64

# %% [markdown]
# # Новый раздел

# %%
df
# Out:
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 13 columns]

# %%
print(df.shape)
print(df)
df=df.dropna()
print(df)
# Out:
# (1192, 13)
#         country  ...                                     source_website
# 0     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4     Argentina  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...         ...  ...                                                ...
# 1187      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1188      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1189      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1190      Wales  ...  https://coronavirus.data.gov.uk/details/health...
# 1191      Wales  ...  https://coronavirus.data.gov.uk/details/health...
#
# [1192 rows x 13 columns]
# ...

# %%
 df=df.reset_index()

# %%
df.vaccines.value_counts()
# Out:
# Pfizer/BioNTech                        639
# Moderna, Pfizer/BioNTech               217
# Sputnik V                               53
# Pfizer/BioNTech, Sinopharm              44
# CNBG, Sinovac                           37
# Oxford/AstraZeneca, Pfizer/BioNTech     31
# Sinovac                                 13
# Sinopharm                                8
# Covaxin, Covishield                      5
# Name: vaccines, dtype: int64

# %%
len(df.source_name.unique())
# Out:
# 33

# %%
df[309:340]
# Out:
#      index  ...                                     source_website
# 309    309  ...  https://covid19.ssi.dk/overvagningsdata/vaccin...
# 310    341  ...              https://www.terviseamet.ee/et/uudised
# 311    342  ...              https://www.terviseamet.ee/et/uudised
# 312    343  ...              https://www.terviseamet.ee/et/uudised
# 313    344  ...              https://www.terviseamet.ee/et/uudised
# 314    345  ...              https://www.terviseamet.ee/et/uudised
# 315    346  ...              https://www.terviseamet.ee/et/uudised
# 316    347  ...              https://www.terviseamet.ee/et/uudised
# 317    348  ...              https://www.terviseamet.ee/et/uudised
# 318    349  ...              https://www.terviseamet.ee/et/uudised
# 319    350  ...              https://www.terviseamet.ee/et/uudised
# 320    351  ...              https://www.terviseamet.ee/et/uudised
# 321    352  ...              https://www.terviseamet.ee/et/uudised
# ...

# %%
df.source_name.value_counts()
# Out:
# Ministry of Health                                             308
# National Health Commission                                      60
# National Health Service                                         42
# COVID-19 Canada Open Data Working Group                         37
# Government of Israel                                            33
# Centers for Disease Control and Prevention                      31
# Government of the United Kingdom                                31
# Russian Direct Investment Fund                                  30
# Federal Office of Public Health                                 28
# Secretary of Health                                             27
# Department of Statistics and Health Information                 27
# Extraordinary commissioner for the Covid-19 emergency           25
# Government of Romania                                           24
# Norwegian Institute of Public Health                            24
# ...

# %%
df.loc[1][:4]
# Out:
# index                1
# country      Argentina
# iso_code           ARG
# date        2020-12-30
# Name: 1, dtype: object

# %%
df.iso_code[:10]
# Out:
# 0    ARG
# 1    ARG
# 2    ARG
# 3    ARG
# 4    ARG
# 5    ARG
# 6    ARG
# 7    ARG
# 8    ARG
# 9    ARG
# Name: iso_code, dtype: object

# %%
df1=df

# %%
a=df1.shape[0]
print(a)
for i in range(0,a):
  print(a)
  print(i)
  print(df1.total_vaccinations[i])
  if df1.total_vaccinations[i]<100000:
     df1=df1.drop([i])
     a=df1.shape[0]

df1
# Out:
# 1047
# 1047
# 0
# 700.0
# 1046
# 1
# 499477.50933333335
# 1046
# 2
# 32013.0
# 1045
# 3
# 499477.50933333335
# 1045
# 4
# 499477.50933333335
# 1045
# 5
# 499477.50933333335
# 1045
# 6
# 39599.0
# 1044
# 7
# 499477.50933333335
# 1044
# 8
# 499477.50933333335
# 1044
# 9
# 499477.50933333335
# 1044
# 10
# 107542.0
# 1044
# 11
# 499477.50933333335
# 1044
# 12
# 499477.50933333335
# 1044
# 13
# 499477.50933333335
# 1044
# 14
# 499477.50933333335
# 1044
# 15
# 166833.0
# 1044
# 16
# 499477.50933333335
# 1044
# 17
# 200759.0
# 1044
# 18
# 499477.50933333335
# 1044
# 19
# 499477.50933333335
# 1044
# 20
# 499477.50933333335
# 1044
# 21
# 499477.50933333335
# 1044
# 22
# 247933.0
# 1044
# 23
# 8360.0
# 1043
# 24
# 499477.50933333335
# 1043
# 25
# 15095.0
# 1042
# 26
# 30150.0
# 1041
# 27
# 31525.0
# 1040
# 28
# 31885.0
# 1039
# 29
# 38545.0
# 1038
# 30
# 52925.0
# 1037
# 31
# 63280.0
# 1036
# 32
# 74100.0
# 1035
# 33
# 84380.0
# 1034
# 34
# 87195.0
# 1033
# 35
# 102790.0
# 1033
# 36
# ...

# %%
df2=df.iloc[20:30, :5]

# %%
df
# Out:
#       index  ...                                     source_website
# 0         0  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1         1  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2         2  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3         3  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4         4  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...     ...  ...                                                ...
# 1042   1149  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1043   1150  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1044   1151  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1045   1152  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1046   1153  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
#
# [1047 rows x 14 columns]

# %%
df3=df
k=0

# %%
for m in range(0,a):
  i=df3.date[m]
  if (i <'2020-12-20')&(i>'2021-01-05'):
    df3=df3.drop([m])
    a=df3.shape[1]
df3
# Out:
#       index  ...                                     source_website
# 0         0  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1         1  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2         2  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3         3  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4         4  ...  http://datos.salud.gob.ar/dataset/vacunas-cont...
# ...     ...  ...                                                ...
# 1042   1149  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1043   1150  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1044   1151  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1045   1152  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 1046   1153  ...  https://covid.cdc.gov/covid-data-tracker/#vacc...
#
# [1047 rows x 14 columns]

# %% [markdown]
# # Новый раздел

# %%
l=preprocessing.LabelEncoder()
mapped=l.fit_transform(df['date'])
df['date1']=mapped

# %%
df4=df
a=df4.shape[0]
print(a)
for i in range(0,a):
  print(a)
  print(i)
  print(df4.total_vaccinations[i])
  if df4.country[i]=="Argentina":
    print("")
  else:
     df4=df4.drop([i])
     a=df4.shape[0]

df4
# Out:
# 1047
# 1047
# 0
# 700.0
#
# 1047
# 1
# 499477.50933333335
#
# 1047
# 2
# 32013.0
#
# 1047
# 3
# 499477.50933333335
#
# 1047
# 4
# 499477.50933333335
#
# 1047
# 5
# 499477.50933333335
#
# 1047
# 6
# 39599.0
#
# 1047
# 7
# 499477.50933333335
#
# 1047
# 8
# 499477.50933333335
#
# 1047
# 9
# 499477.50933333335
#
# 1047
# 10
# 107542.0
#
# 1047
# 11
# 499477.50933333335
#
# 1047
# 12
# 499477.50933333335
#
# 1047
# 13
# 499477.50933333335
#
# 1047
# 14
# 499477.50933333335
#
# 1047
# 15
# 166833.0
#
# 1047
# 16
# 499477.50933333335
#
# 1047
# 17
# 200759.0
#
# 1047
# 18
# 499477.50933333335
#
# 1047
# 19
# 499477.50933333335
#
# 1047
# 20
# 499477.50933333335
#
# 1047
# 21
# 499477.50933333335
#
# 1047
# 22
# 247933.0
#
# 1047
# 23
# 8360.0
# 1046
# 24
# 499477.50933333335
# 1045
# 25
# 15095.0
# 1044
# 26
# 30150.0
# 1043
# 27
# 31525.0
# 1042
# 28
# 31885.0
# 1041
# 29
# 38545.0
# 1040
# 30
# 52925.0
# 1039
# 31
# 63280.0
# 1038
# 32
# 74100.0
# 1037
# 33
# 84380.0
# 1036
# 34
# ...

# %%
df5=df.groupby('country')['total_vaccinations'].max()
df5=pd.DataFrame(df5)
print(df5)
k=0
df5["country"]=""
for i in df5.iloc:
  df5.country[k]=i.name
  k=k+1

df5
# Out:
#                       total_vaccinations
# country
# Argentina                   4.994775e+05
# Austria                     4.994775e+05
# Bahrain                     1.435960e+05
# Belgium                     4.994775e+05
# Brazil                      2.854300e+04
# Bulgaria                    4.994775e+05
# Canada                      6.511390e+05
# Chile                       4.994775e+05
# China                       1.500000e+07
# Costa Rica                  4.994775e+05
# Croatia                     4.994775e+05
# Cyprus                      4.994775e+05
# Czechia                     4.994775e+05
# Denmark                     1.820320e+05
# Estonia                     4.994775e+05
# Finland                     4.994775e+05
# France                      5.856640e+05
# Germany                     1.297430e+06
# Gibraltar                   4.994775e+05
# Greece                      4.994775e+05
# Hungary                     4.994775e+05
# Iceland                     4.994775e+05
# ...

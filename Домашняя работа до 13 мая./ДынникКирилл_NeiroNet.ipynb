# %% [markdown]
# Дынник Кирилл

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b0e91b3-52ab-4455-9864-337a3beab36a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b0e91b3-52ab-4455-9864-337a3beab36a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train (7).csv to train (7) (4).csv

# %%
df = pd.read_csv('train (7).csv')
df
# Out:
#       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0               842     0          2.2  ...             0     1            1
# 1              1021     1          0.5  ...             1     0            2
# 2               563     1          0.5  ...             1     0            2
# 3               615     1          2.5  ...             0     0            2
# 4              1821     1          1.2  ...             1     0            1
# ...             ...   ...          ...  ...           ...   ...          ...
# 1995            794     1          0.5  ...             1     0            0
# 1996           1965     1          2.6  ...             1     1            2
# 1997           1911     0          0.9  ...             1     0            3
# 1998           1512     0          0.9  ...             1     1            0
# 1999            510     1          2.0  ...             1     1            3
#
# [2000 rows x 21 columns]

# %%
#удалим некоторые столбцы так, как по заданию должно быть 10 входных признаков (В нейросети). А если я сделаю для остальных методов признаков больше, то сравнивать их будет не корректно, поэтому для всех методов будет 10 признаков
df = df.drop(['clock_speed'], axis=1)
df = df.drop(['m_dep'], axis=1)
df = df.drop(['int_memory'], axis=1)
df = df.drop(['mobile_wt'], axis=1)
df = df.drop(['n_cores'], axis=1)
df = df.drop(['px_height'], axis=1)
df = df.drop(['px_width'], axis=1)
df = df.drop(['blue'], axis=1)
df = df.drop(['pc'], axis=1)
df = df.drop(['sc_h'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['price_range'], axis=1)
Y = df['price_range']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
df
# Out:
#       battery_power  dual_sim  fc  ...  touch_screen  wifi  price_range
# 0               842         0   1  ...             0     1            1
# 1              1021         1   0  ...             1     0            2
# 2               563         1   2  ...             1     0            2
# 3               615         0   0  ...             0     0            2
# 4              1821         0  13  ...             1     0            1
# ...             ...       ...  ..  ...           ...   ...          ...
# 1995            794         1   0  ...             1     0            0
# 1996           1965         1   0  ...             1     1            2
# 1997           1911         1   1  ...             1     0            3
# 1998           1512         0   4  ...             1     1            0
# 1999            510         1   5  ...             1     1            3
#
# [2000 rows x 11 columns]

# %% [markdown]
# #LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
answer_pred = model.predict(X_train)
print(model.score(X_test, y_test))
# Out:
# 0.6033333333333334
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# #NeiroNet

# %%
from keras.utils import np_utils
Y = np_utils.to_categorical(Y, num_classes=5)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

#входной слой с 10-ю входными признаками
model.add(Dense(5, input_dim=10, activation='relu'))

#скрытые слои
model.add(Dense(15, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))

#выходной слой
model.add(Dense(5, activation='softmax'))

# %%
model.compile(optimizer="rmsprop",  loss="categorical_crossentropy", metrics=['accuracy'])

# %%
model.fit(X, Y, epochs = 15)
# Out:
# Epoch 1/15
# 63/63 [==============================] - 1s 2ms/step - loss: 2.8853 - accuracy: 0.2921
# Epoch 2/15
# 63/63 [==============================] - 0s 2ms/step - loss: 1.2446 - accuracy: 0.3990
# Epoch 3/15
# 63/63 [==============================] - 0s 2ms/step - loss: 1.1717 - accuracy: 0.3903
# Epoch 4/15
# 63/63 [==============================] - 0s 2ms/step - loss: 1.1181 - accuracy: 0.4606
# Epoch 5/15
# 63/63 [==============================] - 0s 2ms/step - loss: 1.0665 - accuracy: 0.4908
# Epoch 6/15
# 63/63 [==============================] - 0s 2ms/step - loss: 1.0524 - accuracy: 0.5226
# Epoch 7/15
# 63/63 [==============================] - 0s 2ms/step - loss: 1.0080 - accuracy: 0.5606
# Epoch 8/15
# 63/63 [==============================] - 0s 2ms/step - loss: 0.9804 - accuracy: 0.5544
# Epoch 9/15
# 63/63 [==============================] - 0s 2ms/step - loss: 0.9225 - accuracy: 0.5922
# Epoch 10/15
# ...

# %% [markdown]
# #LightGBM

# %%
from lightgbm import LGBMClassifier

model = LGBMClassifier()
model.fit(X_train, y_train)
answer_pred = model.predict(X_train)
print(model.score(X_test, y_test))
# Out:
# 0.7783333333333333

# %% [markdown]
# Можно сделать вывод, что лучше всего с данной задачей справляется LightGBM, но можно попробовать добиться лучшего результата у нейросети с помощью увиличения эпох (по заданию должно быть именно 15 эпох)

# %%
from keras.utils import np_utils
Y = np_utils.to_categorical(Y, num_classes=5)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

#входной слой с 10-ю входными признаками
model.add(Dense(5, input_dim=10, activation='relu'))

#скрытые слои
model.add(Dense(15, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))

#выходной слой
model.add(Dense(5, activation='softmax'))

# %%
model.compile(optimizer="rmsprop",  loss="categorical_crossentropy", metrics=['accuracy'])

# %%
model.fit(X, Y, epochs = 200)
# Out:
# Epoch 1/200
# 63/63 [==============================] - 1s 2ms/step - loss: 1.4909 - accuracy: 0.2983
# Epoch 2/200
# 63/63 [==============================] - 0s 2ms/step - loss: 1.2360 - accuracy: 0.4058
# Epoch 3/200
# 63/63 [==============================] - 0s 2ms/step - loss: 1.1492 - accuracy: 0.4021
# Epoch 4/200
# 63/63 [==============================] - 0s 2ms/step - loss: 1.0996 - accuracy: 0.4490
# Epoch 5/200
# 63/63 [==============================] - 0s 2ms/step - loss: 1.0592 - accuracy: 0.4616
# Epoch 6/200
# 63/63 [==============================] - 0s 2ms/step - loss: 1.0078 - accuracy: 0.4764
# Epoch 7/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.9681 - accuracy: 0.5073
# Epoch 8/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.9443 - accuracy: 0.5403
# Epoch 9/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.9201 - accuracy: 0.5553
# Epoch 10/200
# ...

# %%
Как видим с помощью нейросети мы смогли добиться accuracy даже 83% (например на 198-ой эпохе). Этот доказывает, что в данной задаче всё же лучше работает нейросеть.

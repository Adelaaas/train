# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv("train (7).csv")
df
# Out:
#       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0               842     0          2.2  ...             0     1            1
# 1              1021     1          0.5  ...             1     0            2
# 2               563     1          0.5  ...             1     0            2
# 3               615     1          2.5  ...             0     0            2
# 4              1821     1          1.2  ...             1     0            1
# ...             ...   ...          ...  ...           ...   ...          ...
# 1995            794     1          0.5  ...             1     0            0
# 1996           1965     1          2.6  ...             1     1            2
# 1997           1911     0          0.9  ...             1     0            3
# 1998           1512     0          0.9  ...             1     1            0
# 1999            510     1          2.0  ...             1     1            3
#
# [2000 rows x 21 columns]

# %%
#KNN
X = df.drop(['price_range'], axis = 1)
y = df['price_range']

X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=1/3, random_state=42)

scores = []
for i in range(1,15):
    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    answers = knn.predict(X_test) # метод predict возвращыет вектор ответов для X_test
    #print(answers)
    scores.append(knn.score(X_test,y_test))
print(max(scores))
# Out:
# 0.9385307346326837

# %%
#XGBoost
modelXGBoost = XGBClassifier()
modelXGBoost.fit(X_train, y_train)

print(modelXGBoost.score(X_test, y_test))
# Out:
# 0.8920539730134932

# %%
X = df.iloc[:, :20]
Y = df.iloc[:, 20]

modelNeuroph = Sequential()

modelNeuroph.add(Dense(1, input_dim = 20, activation = 'relu'))

modelNeuroph.add(Dense(4, activation = 'relu'))

modelNeuroph.add(Dense(1, activation = 'sigmoid'))

modelNeuroph.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ['accuracy', 'Recall'])

modelNeuroph.fit(X, Y, epochs = 50, batch_size = 10)

y_pred = modelNeuroph
# Out:
# Epoch 1/50
# 200/200 [==============================] - 1s 1ms/step - loss: -838.7432 - accuracy: 0.2646 - recall: 1.0000
# Epoch 2/50
# 200/200 [==============================] - 0s 1ms/step - loss: -2438.2849 - accuracy: 0.2448 - recall: 1.0000
# Epoch 3/50
# 200/200 [==============================] - 0s 1ms/step - loss: -5811.1008 - accuracy: 0.2453 - recall: 1.0000
# Epoch 4/50
# 200/200 [==============================] - 0s 1ms/step - loss: -11662.5769 - accuracy: 0.2461 - recall: 1.0000
# Epoch 5/50
# 200/200 [==============================] - 0s 1ms/step - loss: -20417.3080 - accuracy: 0.2500 - recall: 1.0000
# Epoch 6/50
# 200/200 [==============================] - 0s 1ms/step - loss: -35281.0533 - accuracy: 0.2429 - recall: 1.0000
# Epoch 7/50
# 200/200 [==============================] - 0s 1ms/step - loss: -48070.9610 - accuracy: 0.2617 - recall: 1.0000
# Epoch 8/50
# ...
